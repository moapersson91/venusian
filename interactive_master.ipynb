# %%
import GUI
# %matplotlib nbagg

# %%
# %matplotlib nbagg
data, orbits = GUI.main(datapath='processed_data/',datafile='venus_specData', 
                regionpath='',regionfile='alexregion', 
                orbitpath='', orbitfile='orbits')
# Out:
# <img src="data:image/png;base64,..." width="900">
# ...

# %%
def save_data(data, orbits, filepath='', filename=''):
    import ipywidgets as widgets

    IO.save_file(data, filepath=filepath, filename=filename)
    
    a = list(data.get())
    b = orbits
    
    progress = sum([b[i] in a for i, _ in enumerate(b)])
    
    progress = widgets.FloatProgress(
        value=progress,
        min=0,
        max=len(b),
        step=1,
        description='Progress:',
        bar_style='info',
        orientation='horizontal'
    )

    display(progress)

# %%
save_data(data, orbits, filepath='', filename='alexregion')
# Out:
# FloatProgress(value=1.0, bar_style='info', description='Progress:', max=11.0)

# %%
len(b)
# Out:
# 11

# %%
a = list(data.get())
orbits = IO.read_file(filepath='', filename='orbits')
b = orbits

# %%
sum([b[i] in a for i, _ in enumerate(b)])
# Out:
# 4

# %%
b
# Out:
# [2905, 2909, 2907, 2910, 2911, 2903, 2904, 2908, 2913, 2912, 2906]

# %%
a = [2903, 2907,2905,2909]

# %%
len(a)
# Out:
# 4

# %%
data.get()
# Out:
# {2903: {'comment': 'commentary'}}
