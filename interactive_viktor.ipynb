# %% [markdown]
# ## Import the Necessary Code
# run the cell below

# %%
from interface import main, save_data  
# %matplotlib nbagg

# %% [markdown]
# ## Run the Program
# run the cell below

# %%
# %matplotlib nbagg

user = 'v'
regions, orbits = main(datapath='../processed_data', 
                regionpath='regions/',regionfile='region_{}'.format(user), 
                  orbitpath='orbits/', orbitfile='orbits_{}'.format(user))
# Out:
# <img src="data:image/png;base64,..." width="900">
# VBox(children=(HBox(children=(Button(description='prev orbit', style=ButtonStyle()), Button(description='next …

# %% [markdown]
# ### Don't forget to save your work!
#
# run the cell below

# %%
save_data(regions, orbits, filepath='regions', filename='region_{}'.format(user))
# Out:
# 294 out of 1846 : 15.926%
# FloatProgress(value=294.0, bar_style='info', description='Progress:', max=1846.0)

# %%
if False:
    current_orbit = 0
    regions.del_entry(current_orbit, 'comment')

# %% [markdown]
# ## [end]
